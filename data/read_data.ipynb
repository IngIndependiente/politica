# %%
import pandas as pd

# %%
analisis = pd.read_parquet('analisis.parquet')
analisis.head(20)
# Out:
#     id  persona_id                                            resumen  \
# 0    1           1  Juan Pérez, 28 años, ingeniero, preocupado por...
# 1    2           2  María González, 45 años, profesora de Santiago...
# 2    3           3  Carlos Rodríguez, 32 años, empresario, interes...
# 3    4           3   Interés en infraestructura y transporte público.
# 4    5           4  Ana Silva, 26 años, estudiante de medicina, in...
# 5    6           5  Pedro Morales, 55 años, jubilado, preocupado p...
# 6    7           6  Laura Martínez, 35 años, arquitecta, interesad...
# 7    8           7  Pregunta sobre planes para mejorar el deporte ...
# 8    9           8  El usuario saluda al Senador y menciona un par...
# 9   10           7  Pregunta sobre planes para mejorar el deporte ...
# 10  11           8      Referencia a un partido de fútbol compartido.
# 11  12           8  Interés en conocer propuestas y referencia a e...
# ...
